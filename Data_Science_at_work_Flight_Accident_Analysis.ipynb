# %%
# To enable plotting graphs in Jupyter notebook
# %matplotlib inline 

# Numerical libraries
import numpy as np   

# Import Linear Regression machine learning library
from sklearn.linear_model import LinearRegression

# to handle data in form of rows and columns 
import pandas as pd    

# importing ploting libraries
import matplotlib.pyplot as plt   
import matplotlib.style

#importing seaborn for statistical plots
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: matplotlib in c:\users\humerayasmeen.s\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\humerayasmeen.s\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pillow in c:\users\humerayasmeen.s\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\humerayasmeen.s\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\humerayasmeen.s\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\humerayasmeen.s\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\humerayasmeen.s\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\humerayasmeen.s\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\humerayasmeen.s\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\humerayasmeen.s\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
nltk.download('punkt')

from wordcloud import WordCloud

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import make_scorer, roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\humerayasmeen.s\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\humerayasmeen.s\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\humerayasmeen.s\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# reading the CSV file into pandas dataframe
flight_df = pd.read_excel("aircraft_1.xlsx")

# %%
flight_df
# Out:
#      EventDate            City       State  HasSafetyRec      Mode  \
# 0        44464       Patterson   Louisiana         False  Aviation
# 1        44458    Grass Valley  California         False  Aviation
# 2        44456     Osage Beach    Missouri         False  Aviation
# 3        44455    Battle Creek    Michigan         False  Aviation
# 4        44455       Ypsilanti    Michigan         False  Aviation
# ..         ...             ...         ...           ...       ...
# 540      44065             Tok      Alaska         False  Aviation
# 541      44064        Kotzebue      Alaska         False  Aviation
# 542      44064          Athens       Texas         False  Aviation
# 543      44064       Corsicana       Texas         False  Aviation
# 544      44064  Corpus Christi       Texas         False    Marine
#
#     HighestInjuryLevel  FatalInjuryCount  SeriousInjuryCount  \
# 0                 None                 0                   0
# 1                 None                 0                   0
# 2                 None                 0                   0
# 3                 None                 0                   0
# 4                 None                 0                   0
# ..                 ...               ...                 ...
# 540               None                 0                   0
# 541               None                 0                   0
# 542               None                 0                   0
# 543               None                 0                   0
# 544              Fatal                 4                   6
#
#      MinorInjuryCount           Category  \
# 0                   0        pilot_issue
# 1                   0        pilot_issue
# 2                   0        pilot_issue
# 3                   0        pilot_issue
# 4                   0        pilot_issue
# ..                ...                ...
# 540                 0        pilot_issue
# 541                 0        pilot_issue
# 542                 0        pilot_issue
# 543                 0        pilot_issue
# 544                 0  environment_issue
#
#                                          ProbableCause  \
# 0    The pilot’s failure maintain adequate clearanc...
# 1    The pilot’s failure attain proper touchdown po...
# 2    The pilot flight instructor’s failure ensure l...
# 3    The pilot’s failure maintain directional contr...
# 4    The pilot’s failure maintain directional contr...
# ..                                                 ...
# 540  The student pilot’s failure maintain direction...
# 541  The pilot's failure maintain airspeed conduciv...
# 542  The pilot’s failure extend landing gear approa...
# 543  The student pilot maintain control airplane ta...
# 544  The National Transportation Safety Board deter...
#
#                                               Findings
# 0    Personnel issues - Psychological - Attention/m...
# 1    Aircraft - Aircraft systems - Communications s...
# 2    Personnel issues - Task performance - Use of e...
# 3    Personnel issues - Task performance - Use of e...
# 4    Personnel issues - Task performance - Use of e...
# ..                                                 ...
# 540  Aircraft - Aircraft oper/perf/capability - Per...
# 541  Aircraft - Aircraft oper/perf/capability - Per...
# 542  Personnel issues - Task performance - Use of e...
# 543  Aircraft - Aircraft oper/perf/capability - Per...
# 544  Organizational issues - Support/oversight/moni...
#
# [545 rows x 12 columns]

# %%
#flight_df.drop(columns = ['NtsbNo', 'EventType'], inplace=True)

# %%
#flight_df.drop(columns = ['DocketUrl', 'ReportType', 'N#', 'ReportNo'], inplace=True)

# %%
#flight_df.drop(columns = ['Mkey', 'OriginalPublishedDate', 'Country'], inplace=True)

# %%
#flight_df[flight_df['HasSafetyRec'] == True]

# %%
flight_df.drop(columns=['Unnamed: 0', 'EventDate'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 flight_df.drop(columns=['Unnamed: 0', 'EventDate'], inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
#import dateutil.parser

#d = dateutil.parser.parse(flight_df['EventDate'][0]).strftime('%m/%d/%Y')
#print(d)

# %%
#flight_df['EventDate'] = flight_df['EventDate'].apply(lambda x: dateutil.parser.parse(x).strftime('%m/%d/%Y'))

# %%
#flight_df

# %%
flight_df.describe()
# Out:
#           EventDate  FatalInjuryCount  SeriousInjuryCount  MinorInjuryCount
# count    545.000000        545.000000          545.000000        545.000000
# mean   44245.383486          0.023853            0.110092          0.256881
# std      110.683263          0.280132            0.423124          0.565615
# min    44064.000000          0.000000            0.000000          0.000000
# 25%    44141.000000          0.000000            0.000000          0.000000
# 50%    44266.000000          0.000000            0.000000          0.000000
# 75%    44337.000000          0.000000            0.000000          0.000000
# max    44464.000000          4.000000            6.000000          3.000000

# %%
flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EventDate           545 non-null    int64
#  1   City                545 non-null    object
#  2   State               545 non-null    object
#  3   HasSafetyRec        545 non-null    bool
#  4   Mode                545 non-null    object
#  5   HighestInjuryLevel  545 non-null    object
#  6   FatalInjuryCount    545 non-null    int64
#  7   SeriousInjuryCount  545 non-null    int64
#  8   MinorInjuryCount    545 non-null    int64
#  9   Category            545 non-null    object
#  10  ProbableCause       545 non-null    object
#  11  Findings            545 non-null    object
# dtypes: bool(1), int64(4), object(7)
# memory usage: 47.5+ KB

# %%
flight_df['EventDate'] = pd.to_datetime(flight_df['EventDate'])

# %%
flight_df
# Out:
#                         EventDate            City       State  HasSafetyRec  \
# 0   1970-01-01 00:00:00.000044464       Patterson   Louisiana         False
# 1   1970-01-01 00:00:00.000044458    Grass Valley  California         False
# 2   1970-01-01 00:00:00.000044456     Osage Beach    Missouri         False
# 3   1970-01-01 00:00:00.000044455    Battle Creek    Michigan         False
# 4   1970-01-01 00:00:00.000044455       Ypsilanti    Michigan         False
# ..                            ...             ...         ...           ...
# 540 1970-01-01 00:00:00.000044065             Tok      Alaska         False
# 541 1970-01-01 00:00:00.000044064        Kotzebue      Alaska         False
# 542 1970-01-01 00:00:00.000044064          Athens       Texas         False
# 543 1970-01-01 00:00:00.000044064       Corsicana       Texas         False
# 544 1970-01-01 00:00:00.000044064  Corpus Christi       Texas         False
#
#          Mode HighestInjuryLevel  FatalInjuryCount  SeriousInjuryCount  \
# 0    Aviation               None                 0                   0
# 1    Aviation               None                 0                   0
# 2    Aviation               None                 0                   0
# 3    Aviation               None                 0                   0
# 4    Aviation               None                 0                   0
# ..        ...                ...               ...                 ...
# 540  Aviation               None                 0                   0
# 541  Aviation               None                 0                   0
# 542  Aviation               None                 0                   0
# 543  Aviation               None                 0                   0
# 544    Marine              Fatal                 4                   6
#
#      MinorInjuryCount           Category  \
# 0                   0        pilot_issue
# 1                   0        pilot_issue
# 2                   0        pilot_issue
# 3                   0        pilot_issue
# 4                   0        pilot_issue
# ..                ...                ...
# 540                 0        pilot_issue
# 541                 0        pilot_issue
# 542                 0        pilot_issue
# 543                 0        pilot_issue
# 544                 0  environment_issue
#
#                                          ProbableCause  \
# 0    The pilot’s failure maintain adequate clearanc...
# 1    The pilot’s failure attain proper touchdown po...
# 2    The pilot flight instructor’s failure ensure l...
# 3    The pilot’s failure maintain directional contr...
# 4    The pilot’s failure maintain directional contr...
# ..                                                 ...
# 540  The student pilot’s failure maintain direction...
# 541  The pilot's failure maintain airspeed conduciv...
# 542  The pilot’s failure extend landing gear approa...
# 543  The student pilot maintain control airplane ta...
# 544  The National Transportation Safety Board deter...
#
#                                               Findings
# 0    Personnel issues - Psychological - Attention/m...
# 1    Aircraft - Aircraft systems - Communications s...
# 2    Personnel issues - Task performance - Use of e...
# 3    Personnel issues - Task performance - Use of e...
# 4    Personnel issues - Task performance - Use of e...
# ..                                                 ...
# 540  Aircraft - Aircraft oper/perf/capability - Per...
# 541  Aircraft - Aircraft oper/perf/capability - Per...
# 542  Personnel issues - Task performance - Use of e...
# 543  Aircraft - Aircraft oper/perf/capability - Per...
# 544  Organizational issues - Support/oversight/moni...
#
# [545 rows x 12 columns]

# %%
flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EventDate           545 non-null    datetime64[ns]
#  1   City                545 non-null    object
#  2   State               545 non-null    object
#  3   HasSafetyRec        545 non-null    bool
#  4   Mode                545 non-null    object
#  5   HighestInjuryLevel  545 non-null    object
#  6   FatalInjuryCount    545 non-null    int64
#  7   SeriousInjuryCount  545 non-null    int64
#  8   MinorInjuryCount    545 non-null    int64
#  9   Category            545 non-null    object
#  10  ProbableCause       545 non-null    object
#  11  Findings            545 non-null    object
# dtypes: bool(1), datetime64[ns](1), int64(3), object(7)
# memory usage: 47.5+ KB

# %%
#flight_df.drop(columns = ['EventDate'], inplace=True)

# %%
flight_df
# Out:
#                         EventDate            City       State  HasSafetyRec  \
# 0   1970-01-01 00:00:00.000044464       Patterson   Louisiana         False
# 1   1970-01-01 00:00:00.000044458    Grass Valley  California         False
# 2   1970-01-01 00:00:00.000044456     Osage Beach    Missouri         False
# 3   1970-01-01 00:00:00.000044455    Battle Creek    Michigan         False
# 4   1970-01-01 00:00:00.000044455       Ypsilanti    Michigan         False
# ..                            ...             ...         ...           ...
# 540 1970-01-01 00:00:00.000044065             Tok      Alaska         False
# 541 1970-01-01 00:00:00.000044064        Kotzebue      Alaska         False
# 542 1970-01-01 00:00:00.000044064          Athens       Texas         False
# 543 1970-01-01 00:00:00.000044064       Corsicana       Texas         False
# 544 1970-01-01 00:00:00.000044064  Corpus Christi       Texas         False
#
#          Mode HighestInjuryLevel  FatalInjuryCount  SeriousInjuryCount  \
# 0    Aviation               None                 0                   0
# 1    Aviation               None                 0                   0
# 2    Aviation               None                 0                   0
# 3    Aviation               None                 0                   0
# 4    Aviation               None                 0                   0
# ..        ...                ...               ...                 ...
# 540  Aviation               None                 0                   0
# 541  Aviation               None                 0                   0
# 542  Aviation               None                 0                   0
# 543  Aviation               None                 0                   0
# 544    Marine              Fatal                 4                   6
#
#      MinorInjuryCount           Category  \
# 0                   0        pilot_issue
# 1                   0        pilot_issue
# 2                   0        pilot_issue
# 3                   0        pilot_issue
# 4                   0        pilot_issue
# ..                ...                ...
# 540                 0        pilot_issue
# 541                 0        pilot_issue
# 542                 0        pilot_issue
# 543                 0        pilot_issue
# 544                 0  environment_issue
#
#                                          ProbableCause  \
# 0    The pilot’s failure maintain adequate clearanc...
# 1    The pilot’s failure attain proper touchdown po...
# 2    The pilot flight instructor’s failure ensure l...
# 3    The pilot’s failure maintain directional contr...
# 4    The pilot’s failure maintain directional contr...
# ..                                                 ...
# 540  The student pilot’s failure maintain direction...
# 541  The pilot's failure maintain airspeed conduciv...
# 542  The pilot’s failure extend landing gear approa...
# 543  The student pilot maintain control airplane ta...
# 544  The National Transportation Safety Board deter...
#
#                                               Findings
# 0    Personnel issues - Psychological - Attention/m...
# 1    Aircraft - Aircraft systems - Communications s...
# 2    Personnel issues - Task performance - Use of e...
# 3    Personnel issues - Task performance - Use of e...
# 4    Personnel issues - Task performance - Use of e...
# ..                                                 ...
# 540  Aircraft - Aircraft oper/perf/capability - Per...
# 541  Aircraft - Aircraft oper/perf/capability - Per...
# 542  Personnel issues - Task performance - Use of e...
# 543  Aircraft - Aircraft oper/perf/capability - Per...
# 544  Organizational issues - Support/oversight/moni...
#
# [545 rows x 12 columns]

# %%
#flight_df.set_index(keys='Time_Stamp',drop=True,inplace=True)
flight_df.head()
# Out:
#                       EventDate          City       State  HasSafetyRec  \
# 0 1970-01-01 00:00:00.000044464     Patterson   Louisiana         False
# 1 1970-01-01 00:00:00.000044458  Grass Valley  California         False
# 2 1970-01-01 00:00:00.000044456   Osage Beach    Missouri         False
# 3 1970-01-01 00:00:00.000044455  Battle Creek    Michigan         False
# 4 1970-01-01 00:00:00.000044455     Ypsilanti    Michigan         False
#
#        Mode HighestInjuryLevel  FatalInjuryCount  SeriousInjuryCount  \
# 0  Aviation               None                 0                   0
# 1  Aviation               None                 0                   0
# 2  Aviation               None                 0                   0
# 3  Aviation               None                 0                   0
# 4  Aviation               None                 0                   0
#
#    MinorInjuryCount     Category  \
# 0                 0  pilot_issue
# 1                 0  pilot_issue
# 2                 0  pilot_issue
# 3                 0  pilot_issue
# 4                 0  pilot_issue
#
#                                        ProbableCause  \
# 0  The pilot’s failure maintain adequate clearanc...
# 1  The pilot’s failure attain proper touchdown po...
# 2  The pilot flight instructor’s failure ensure l...
# 3  The pilot’s failure maintain directional contr...
# 4  The pilot’s failure maintain directional contr...
#
#                                             Findings
# 0  Personnel issues - Psychological - Attention/m...
# 1  Aircraft - Aircraft systems - Communications s...
# 2  Personnel issues - Task performance - Use of e...
# 3  Personnel issues - Task performance - Use of e...
# 4  Personnel issues - Task performance - Use of e...

# %%
flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EventDate           545 non-null    datetime64[ns]
#  1   City                545 non-null    object
#  2   State               545 non-null    object
#  3   HasSafetyRec        545 non-null    bool
#  4   Mode                545 non-null    object
#  5   HighestInjuryLevel  545 non-null    object
#  6   FatalInjuryCount    545 non-null    int64
#  7   SeriousInjuryCount  545 non-null    int64
#  8   MinorInjuryCount    545 non-null    int64
#  9   Category            545 non-null    object
#  10  ProbableCause       545 non-null    object
#  11  Findings            545 non-null    object
# dtypes: bool(1), datetime64[ns](1), int64(3), object(7)
# memory usage: 47.5+ KB

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 20,8
flight_df.plot()
plt.grid();

# %%
flight_df = flight_df.dropna()

# %%
flight_df = flight_df.reset_index()

# %%
flight_df
# Out:
#      index                     EventDate            City       State  \
# 0        0 1970-01-01 00:00:00.000044464       Patterson   Louisiana
# 1        1 1970-01-01 00:00:00.000044458    Grass Valley  California
# 2        2 1970-01-01 00:00:00.000044456     Osage Beach    Missouri
# 3        3 1970-01-01 00:00:00.000044455    Battle Creek    Michigan
# 4        4 1970-01-01 00:00:00.000044455       Ypsilanti    Michigan
# ..     ...                           ...             ...         ...
# 540    540 1970-01-01 00:00:00.000044065             Tok      Alaska
# 541    541 1970-01-01 00:00:00.000044064        Kotzebue      Alaska
# 542    542 1970-01-01 00:00:00.000044064          Athens       Texas
# 543    543 1970-01-01 00:00:00.000044064       Corsicana       Texas
# 544    544 1970-01-01 00:00:00.000044064  Corpus Christi       Texas
#
#      HasSafetyRec      Mode HighestInjuryLevel  FatalInjuryCount  \
# 0           False  Aviation               None                 0
# 1           False  Aviation               None                 0
# 2           False  Aviation               None                 0
# 3           False  Aviation               None                 0
# 4           False  Aviation               None                 0
# ..            ...       ...                ...               ...
# 540         False  Aviation               None                 0
# 541         False  Aviation               None                 0
# 542         False  Aviation               None                 0
# 543         False  Aviation               None                 0
# 544         False    Marine              Fatal                 4
#
#      SeriousInjuryCount  MinorInjuryCount           Category  \
# 0                     0                 0        pilot_issue
# 1                     0                 0        pilot_issue
# 2                     0                 0        pilot_issue
# 3                     0                 0        pilot_issue
# 4                     0                 0        pilot_issue
# ..                  ...               ...                ...
# 540                   0                 0        pilot_issue
# 541                   0                 0        pilot_issue
# 542                   0                 0        pilot_issue
# 543                   0                 0        pilot_issue
# 544                   6                 0  environment_issue
#
#                                          ProbableCause  \
# 0    The pilot’s failure maintain adequate clearanc...
# 1    The pilot’s failure attain proper touchdown po...
# 2    The pilot flight instructor’s failure ensure l...
# 3    The pilot’s failure maintain directional contr...
# 4    The pilot’s failure maintain directional contr...
# ..                                                 ...
# 540  The student pilot’s failure maintain direction...
# 541  The pilot's failure maintain airspeed conduciv...
# 542  The pilot’s failure extend landing gear approa...
# 543  The student pilot maintain control airplane ta...
# 544  The National Transportation Safety Board deter...
#
#                                               Findings
# 0    Personnel issues - Psychological - Attention/m...
# 1    Aircraft - Aircraft systems - Communications s...
# 2    Personnel issues - Task performance - Use of e...
# 3    Personnel issues - Task performance - Use of e...
# 4    Personnel issues - Task performance - Use of e...
# ..                                                 ...
# 540  Aircraft - Aircraft oper/perf/capability - Per...
# 541  Aircraft - Aircraft oper/perf/capability - Per...
# 542  Personnel issues - Task performance - Use of e...
# 543  Aircraft - Aircraft oper/perf/capability - Per...
# 544  Organizational issues - Support/oversight/moni...
#
# [545 rows x 13 columns]

# %%
flight_df.drop(columns=['index'])
# Out:
#                         EventDate            City       State  HasSafetyRec  \
# 0   1970-01-01 00:00:00.000044464       Patterson   Louisiana         False
# 1   1970-01-01 00:00:00.000044458    Grass Valley  California         False
# 2   1970-01-01 00:00:00.000044456     Osage Beach    Missouri         False
# 3   1970-01-01 00:00:00.000044455    Battle Creek    Michigan         False
# 4   1970-01-01 00:00:00.000044455       Ypsilanti    Michigan         False
# ..                            ...             ...         ...           ...
# 540 1970-01-01 00:00:00.000044065             Tok      Alaska         False
# 541 1970-01-01 00:00:00.000044064        Kotzebue      Alaska         False
# 542 1970-01-01 00:00:00.000044064          Athens       Texas         False
# 543 1970-01-01 00:00:00.000044064       Corsicana       Texas         False
# 544 1970-01-01 00:00:00.000044064  Corpus Christi       Texas         False
#
#          Mode HighestInjuryLevel  FatalInjuryCount  SeriousInjuryCount  \
# 0    Aviation               None                 0                   0
# 1    Aviation               None                 0                   0
# 2    Aviation               None                 0                   0
# 3    Aviation               None                 0                   0
# 4    Aviation               None                 0                   0
# ..        ...                ...               ...                 ...
# 540  Aviation               None                 0                   0
# 541  Aviation               None                 0                   0
# 542  Aviation               None                 0                   0
# 543  Aviation               None                 0                   0
# 544    Marine              Fatal                 4                   6
#
#      MinorInjuryCount           Category  \
# 0                   0        pilot_issue
# 1                   0        pilot_issue
# 2                   0        pilot_issue
# 3                   0        pilot_issue
# 4                   0        pilot_issue
# ..                ...                ...
# 540                 0        pilot_issue
# 541                 0        pilot_issue
# 542                 0        pilot_issue
# 543                 0        pilot_issue
# 544                 0  environment_issue
#
#                                          ProbableCause  \
# 0    The pilot’s failure maintain adequate clearanc...
# 1    The pilot’s failure attain proper touchdown po...
# 2    The pilot flight instructor’s failure ensure l...
# 3    The pilot’s failure maintain directional contr...
# 4    The pilot’s failure maintain directional contr...
# ..                                                 ...
# 540  The student pilot’s failure maintain direction...
# 541  The pilot's failure maintain airspeed conduciv...
# 542  The pilot’s failure extend landing gear approa...
# 543  The student pilot maintain control airplane ta...
# 544  The National Transportation Safety Board deter...
#
#                                               Findings
# 0    Personnel issues - Psychological - Attention/m...
# 1    Aircraft - Aircraft systems - Communications s...
# 2    Personnel issues - Task performance - Use of e...
# 3    Personnel issues - Task performance - Use of e...
# 4    Personnel issues - Task performance - Use of e...
# ..                                                 ...
# 540  Aircraft - Aircraft oper/perf/capability - Per...
# 541  Aircraft - Aircraft oper/perf/capability - Per...
# 542  Personnel issues - Task performance - Use of e...
# 543  Aircraft - Aircraft oper/perf/capability - Per...
# 544  Organizational issues - Support/oversight/moni...
#
# [545 rows x 12 columns]

# %%
flight_df['Mode'].value_counts()
# Out:
# Aviation    536
# Marine        8
# Pipeline      1
# Name: Mode, dtype: int64

# %%
flight_df['HighestInjuryLevel'].value_counts()
# Out:
# None       391
# Minor      102
# Serious     47
# Fatal        5
# Name: HighestInjuryLevel, dtype: int64

# %%
flight_df['FatalInjuryCount'].value_counts()
# Out:
# 0    540
# 4      2
# 1      2
# 3      1
# Name: FatalInjuryCount, dtype: int64

# %%
sns.countplot(flight_df['FatalInjuryCount'])
# Out:
# <AxesSubplot:xlabel='FatalInjuryCount', ylabel='count'>

# %%
sns.countplot(flight_df['HighestInjuryLevel'])
# Out:
# <AxesSubplot:xlabel='HighestInjuryLevel', ylabel='count'>

# %%
sns.countplot(flight_df['Mode'])
# Out:
# <AxesSubplot:xlabel='Mode', ylabel='count'>

# %%
flight_df
# Out:
#      index                     EventDate            City       State  \
# 0        0 1970-01-01 00:00:00.000044464       Patterson   Louisiana
# 1        1 1970-01-01 00:00:00.000044458    Grass Valley  California
# 2        2 1970-01-01 00:00:00.000044456     Osage Beach    Missouri
# 3        3 1970-01-01 00:00:00.000044455    Battle Creek    Michigan
# 4        4 1970-01-01 00:00:00.000044455       Ypsilanti    Michigan
# ..     ...                           ...             ...         ...
# 540    540 1970-01-01 00:00:00.000044065             Tok      Alaska
# 541    541 1970-01-01 00:00:00.000044064        Kotzebue      Alaska
# 542    542 1970-01-01 00:00:00.000044064          Athens       Texas
# 543    543 1970-01-01 00:00:00.000044064       Corsicana       Texas
# 544    544 1970-01-01 00:00:00.000044064  Corpus Christi       Texas
#
#      HasSafetyRec      Mode HighestInjuryLevel  FatalInjuryCount  \
# 0           False  Aviation               None                 0
# 1           False  Aviation               None                 0
# 2           False  Aviation               None                 0
# 3           False  Aviation               None                 0
# 4           False  Aviation               None                 0
# ..            ...       ...                ...               ...
# 540         False  Aviation               None                 0
# 541         False  Aviation               None                 0
# 542         False  Aviation               None                 0
# 543         False  Aviation               None                 0
# 544         False    Marine              Fatal                 4
#
#      SeriousInjuryCount  MinorInjuryCount           Category  \
# 0                     0                 0        pilot_issue
# 1                     0                 0        pilot_issue
# 2                     0                 0        pilot_issue
# 3                     0                 0        pilot_issue
# 4                     0                 0        pilot_issue
# ..                  ...               ...                ...
# 540                   0                 0        pilot_issue
# 541                   0                 0        pilot_issue
# 542                   0                 0        pilot_issue
# 543                   0                 0        pilot_issue
# 544                   6                 0  environment_issue
#
#                                          ProbableCause  \
# 0    The pilot’s failure maintain adequate clearanc...
# 1    The pilot’s failure attain proper touchdown po...
# 2    The pilot flight instructor’s failure ensure l...
# 3    The pilot’s failure maintain directional contr...
# 4    The pilot’s failure maintain directional contr...
# ..                                                 ...
# 540  The student pilot’s failure maintain direction...
# 541  The pilot's failure maintain airspeed conduciv...
# 542  The pilot’s failure extend landing gear approa...
# 543  The student pilot maintain control airplane ta...
# 544  The National Transportation Safety Board deter...
#
#                                               Findings
# 0    Personnel issues - Psychological - Attention/m...
# 1    Aircraft - Aircraft systems - Communications s...
# 2    Personnel issues - Task performance - Use of e...
# 3    Personnel issues - Task performance - Use of e...
# 4    Personnel issues - Task performance - Use of e...
# ..                                                 ...
# 540  Aircraft - Aircraft oper/perf/capability - Per...
# 541  Aircraft - Aircraft oper/perf/capability - Per...
# 542  Personnel issues - Task performance - Use of e...
# 543  Aircraft - Aircraft oper/perf/capability - Per...
# 544  Organizational issues - Support/oversight/moni...
#
# [545 rows x 13 columns]

# %%
flight_df.groupby('Category').count()
# Out:
#                    index  EventDate  City  State  HasSafetyRec  Mode  \
# Category
# environment_issue     32         32    32     32            32    32
# flight_issue          37         37    37     37            37    37
# pilot_issue          476        476   476    476           476   476
#
#                    HighestInjuryLevel  FatalInjuryCount  SeriousInjuryCount  \
# Category
# environment_issue                  32                32                  32
# flight_issue                       37                37                  37
# pilot_issue                       476               476                 476
#
#                    MinorInjuryCount  ProbableCause  Findings
# Category
# environment_issue                32             32        32
# flight_issue                     37             37        37
# pilot_issue                     476            476       476

# %% [markdown]
# Year 2020 has large number of accidents

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
flight_df['Findings'] = flight_df['Findings'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
flight_df['Findings'].head()
# Out:
# 0    Personnel issues - Psychological - Attention/m...
# 1    Aircraft - Aircraft systems - Communications s...
# 2    Personnel issues - Task performance - Use equi...
# 3    Personnel issues - Task performance - Use equi...
# 4    Personnel issues - Task performance - Use equi...
# Name: Findings, dtype: object

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
flight_df['Findings'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0      personnel issu - psycholog - attention/monitor...
# 1      aircraft - aircraft system - commun system - (...
# 2      personnel issu - task perform - use equip/info...
# 3      personnel issu - task perform - use equip/info...
# 4      personnel issu - task perform - use equip/info...
#                              ...
# 540    aircraft - aircraft oper/perf/cap - performanc...
# 541    aircraft - aircraft oper/perf/cap - performanc...
# 542    personnel issu - task perform - use equip/info...
# 543    aircraft - aircraft oper/perf/cap - performanc...
# 544    organiz issu - support/oversight/monitor - doc...
# Name: Findings, Length: 545, dtype: object

# %%
stop_words = list(stopwords.words('english'))

# %%
flight_df[flight_df['Category'] == 'environment_issue']['Findings']
# Out:
# 6      Environmental issues - Physical environment - ...
# 10     Environmental issues - Physical environment - ...
# 50     Not determined - Not determined - (general) - ...
# 51     Environmental issues - Conditions/weather/phen...
# 71     Environmental issues - Physical environment - ...
# 92     Environmental issues - Physical environment - ...
# 135    Personnel issues - Action/decision - Action - ...
# 186    Aircraft - Aircraft power plant - Engine contr...
# 197    Environmental issues - Physical environment - ...
# 202    Aircraft - Fluids/misc hardware - Fluids - Fue...
# 209    Not determined - Not determined - (general) - ...
# 215    Environmental issues - Physical environment - ...
# 218    Environmental issues - Physical environment - ...
# 235    Environmental issues - Conditions/weather/phen...
# 264    Environmental issues - Conditions/weather/phen...
# 304    Environmental issues - Physical environment - ...
# 330    Environmental issues - Conditions/weather/phen...
# 350    Environmental issues - Conditions/weather/phen...
# 381    Personnel issues - Action/decision - Info proc...
# 394    Personnel issues - Action/decision - Action - ...
# 399    Personnel issues - Action/decision - Action - ...
# 432    Personnel issues - Physical - Alertness/Fatigu...
# 458    Environmental issues - Physical environment - ...
# 464    Environmental issues - Physical environment - ...
# 465    Environmental issues - Physical environment - ...
# 471    Personnel issues - Action/decision - Action - ...
# 477    Aircraft - Aircraft oper/perf/capability - Per...
# 492    Personnel issues - Task performance - (general...
# 515    Aircraft - Aircraft oper/perf/capability - Per...
# 521    Environmental issues - Physical environment - ...
# 526    Aircraft - Aircraft structures - Doors - Passe...
# 544    Organizational issues - Support/oversight/moni...
# Name: Findings, dtype: object

# %%
corpus_env = flight_df[flight_df['Category'] == 'environment_issue']['Findings'].apply(lambda x: ' '.join([z for z in x.split() if z not in stop_words])) 
corpus_env
# Out:
# 6      Environmental issues - Physical environment - ...
# 10     Environmental issues - Physical environment - ...
# 50     Not determined - Not determined - (general) - ...
# 51     Environmental issues - Conditions/weather/phen...
# 71     Environmental issues - Physical environment - ...
# 92     Environmental issues - Physical environment - ...
# 135    Personnel issues - Action/decision - Action - ...
# 186    Aircraft - Aircraft power plant - Engine contr...
# 197    Environmental issues - Physical environment - ...
# 202    Aircraft - Fluids/misc hardware - Fluids - Fue...
# 209    Not determined - Not determined - (general) - ...
# 215    Environmental issues - Physical environment - ...
# 218    Environmental issues - Physical environment - ...
# 235    Environmental issues - Conditions/weather/phen...
# 264    Environmental issues - Conditions/weather/phen...
# 304    Environmental issues - Physical environment - ...
# 330    Environmental issues - Conditions/weather/phen...
# 350    Environmental issues - Conditions/weather/phen...
# 381    Personnel issues - Action/decision - Info proc...
# 394    Personnel issues - Action/decision - Action - ...
# 399    Personnel issues - Action/decision - Action - ...
# 432    Personnel issues - Physical - Alertness/Fatigu...
# 458    Environmental issues - Physical environment - ...
# 464    Environmental issues - Physical environment - ...
# 465    Environmental issues - Physical environment - ...
# 471    Personnel issues - Action/decision - Action - ...
# 477    Aircraft - Aircraft oper/perf/capability - Per...
# 492    Personnel issues - Task performance - (general...
# 515    Aircraft - Aircraft oper/perf/capability - Per...
# 521    Environmental issues - Physical environment - ...
# 526    Aircraft - Aircraft structures - Doors - Passe...
# 544    Organizational issues - Support/oversight/moni...
# Name: Findings, dtype: object

# %%
wc_a = ' '.join(corpus_env)

# Word Cloud 
from wordcloud import WordCloud
wordcloud = WordCloud(width = 3000, height = 3000, 
                background_color ='black', 
                min_font_size = 10, random_state=100).generate(wc_a)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off")
plt.xlabel('Word Cloud')
plt.tight_layout(pad = 0) 

print("Word Cloud (after cleaning)!!")
plt.show()
# Out:
# Word Cloud (after cleaning)!!

# %%
corpus_flight = flight_df[flight_df['Category'] == 'flight_issue']['Findings'].apply(lambda x: ' '.join([z for z in x.split() if z not in stop_words])) 
corpus_flight
# Out:
# 14     Aircraft - Fluids/misc hardware - Fluids - Fue...
# 15     Aircraft - Aircraft power plant - (general) - ...
# 18     Personnel issues - Task performance - Use equi...
# 60     Personnel issues - Task performance - Use equi...
# 82     Aircraft - Fluids/misc hardware - Fluids - Fue...
# 89     Aircraft - Aircraft systems - Flight control s...
# 104    Aircraft - Fluids/misc hardware - Fluids - Fue...
# 105    Aircraft - Aircraft systems - Air conditioning...
# 122    Environmental issues - Conditions/weather/phen...
# 127    Personnel issues - Task performance - Maintena...
# 133    Environmental issues - Conditions/weather/phen...
# 182    Environmental issues - Physical environment - ...
# 204    Not determined - Not determined - (general) - ...
# 208    Personnel issues - Task performance - Use equi...
# 214    Not determined - Not determined - (general) - ...
# 247    Aircraft - Aircraft systems - Landing gear sys...
# 261    Personnel issues - Experience/knowledge - Trai...
# 291    Not determined - Not determined - (general) - ...
# 323    Not determined - Not determined - (general) - ...
# 336    Aircraft - Aircraft systems - Landing gear sys...
# 339    Aircraft - Aircraft power plant - Engine contr...
# 362    Vessels equipment - Vessel systems/equipment -...
# 363    Personnel issues - Action/decision - Info proc...
# 370    Vessels equipment - Vessel powerplant - Diesel...
# 380    Personnel issues - Action/decision - Action - ...
# 391    Aircraft - Aircraft systems - Landing gear sys...
# 395    Personnel issues - Action/decision - Action - ...
# 439    Aircraft - Fluids/misc hardware - Fluids - Fue...
# 455    Personnel issues - Task performance - Maintena...
# 460    Aircraft - Aircraft systems - Landing gear sys...
# 463    Aircraft - Aircraft systems - Landing gear sys...
# 472    Aircraft - Aircraft systems - Fuel system - Fu...
# 480    Aircraft - Aircraft systems - Landing gear sys...
# 509    Aircraft - Aircraft power plant - Engine (reci...
# 517    Not determined - Not determined - (general) - ...
# 527    Personnel issues - Task performance - Use equi...
# 535    Aircraft - Aircraft power plant - Engine (reci...
# Name: Findings, dtype: object

# %%
wc_b = ' '.join(corpus_flight)

# Word Cloud 
from wordcloud import WordCloud
wordcloud = WordCloud(width = 3000, height = 3000, 
                background_color ='black', 
                min_font_size = 10, random_state=100).generate(wc_b)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off")
plt.xlabel('Word Cloud')
plt.tight_layout(pad = 0) 

print("Word Cloud for Apple_Tweets (after cleaning)!!")
plt.show()
# Out:
# Word Cloud for Apple_Tweets (after cleaning)!!

# %%
corpus_pilot = flight_df[flight_df['Category'] == 'pilot_issue']['Findings'].apply(lambda x: ' '.join([z for z in x.split() if z not in stop_words])) 
corpus_pilot
# Out:
# 0      Personnel issues - Psychological - Attention/m...
# 1      Aircraft - Aircraft systems - Communications s...
# 2      Personnel issues - Task performance - Use equi...
# 3      Personnel issues - Task performance - Use equi...
# 4      Personnel issues - Task performance - Use equi...
#                              ...
# 539    Aircraft - Aircraft oper/perf/capability - Per...
# 540    Aircraft - Aircraft oper/perf/capability - Per...
# 541    Aircraft - Aircraft oper/perf/capability - Per...
# 542    Personnel issues - Task performance - Use equi...
# 543    Aircraft - Aircraft oper/perf/capability - Per...
# Name: Findings, Length: 476, dtype: object

# %%
wc_c = ' '.join(corpus_flight)

# Word Cloud 
from wordcloud import WordCloud
wordcloud = WordCloud(width = 3000, height = 3000, 
                background_color ='black', 
                min_font_size = 10, random_state=100).generate(wc_c)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off")
plt.xlabel('Word Cloud')
plt.tight_layout(pad = 0) 

print("Word Cloud for Apple_Tweets (after cleaning)!!")
plt.show()
# Out:
# Word Cloud for Apple_Tweets (after cleaning)!!

# %%
flight_df
# Out:
#      index                     EventDate            City       State  \
# 0        0 1970-01-01 00:00:00.000044464       Patterson   Louisiana
# 1        1 1970-01-01 00:00:00.000044458    Grass Valley  California
# 2        2 1970-01-01 00:00:00.000044456     Osage Beach    Missouri
# 3        3 1970-01-01 00:00:00.000044455    Battle Creek    Michigan
# 4        4 1970-01-01 00:00:00.000044455       Ypsilanti    Michigan
# ..     ...                           ...             ...         ...
# 540    540 1970-01-01 00:00:00.000044065             Tok      Alaska
# 541    541 1970-01-01 00:00:00.000044064        Kotzebue      Alaska
# 542    542 1970-01-01 00:00:00.000044064          Athens       Texas
# 543    543 1970-01-01 00:00:00.000044064       Corsicana       Texas
# 544    544 1970-01-01 00:00:00.000044064  Corpus Christi       Texas
#
#      HasSafetyRec      Mode HighestInjuryLevel  FatalInjuryCount  \
# 0           False  Aviation               None                 0
# 1           False  Aviation               None                 0
# 2           False  Aviation               None                 0
# 3           False  Aviation               None                 0
# 4           False  Aviation               None                 0
# ..            ...       ...                ...               ...
# 540         False  Aviation               None                 0
# 541         False  Aviation               None                 0
# 542         False  Aviation               None                 0
# 543         False  Aviation               None                 0
# 544         False    Marine              Fatal                 4
#
#      SeriousInjuryCount  MinorInjuryCount           Category  \
# 0                     0                 0        pilot_issue
# 1                     0                 0        pilot_issue
# 2                     0                 0        pilot_issue
# 3                     0                 0        pilot_issue
# 4                     0                 0        pilot_issue
# ..                  ...               ...                ...
# 540                   0                 0        pilot_issue
# 541                   0                 0        pilot_issue
# 542                   0                 0        pilot_issue
# 543                   0                 0        pilot_issue
# 544                   6                 0  environment_issue
#
#                                          ProbableCause  \
# 0    The pilot’s failure maintain adequate clearanc...
# 1    The pilot’s failure attain proper touchdown po...
# 2    The pilot flight instructor’s failure ensure l...
# 3    The pilot’s failure maintain directional contr...
# 4    The pilot’s failure maintain directional contr...
# ..                                                 ...
# 540  The student pilot’s failure maintain direction...
# 541  The pilot's failure maintain airspeed conduciv...
# 542  The pilot’s failure extend landing gear approa...
# 543  The student pilot maintain control airplane ta...
# 544  The National Transportation Safety Board deter...
#
#                                               Findings
# 0    Personnel issues - Psychological - Attention/m...
# 1    Aircraft - Aircraft systems - Communications s...
# 2    Personnel issues - Task performance - Use equi...
# 3    Personnel issues - Task performance - Use equi...
# 4    Personnel issues - Task performance - Use equi...
# ..                                                 ...
# 540  Aircraft - Aircraft oper/perf/capability - Per...
# 541  Aircraft - Aircraft oper/perf/capability - Per...
# 542  Personnel issues - Task performance - Use equi...
# 543  Aircraft - Aircraft oper/perf/capability - Per...
# 544  Organizational issues - Support/oversight/moni...
#
# [545 rows x 13 columns]

# %%
flight_df['ProbableCause']
# Out:
# 0      The pilot’s failure maintain adequate clearanc...
# 1      The pilot’s failure attain proper touchdown po...
# 2      The pilot flight instructor’s failure ensure l...
# 3      The pilot’s failure maintain directional contr...
# 4      The pilot’s failure maintain directional contr...
#                              ...
# 540    The student pilot’s failure maintain direction...
# 541    The pilot's failure maintain airspeed conduciv...
# 542    The pilot’s failure extend landing gear approa...
# 543    The student pilot maintain control airplane ta...
# 544    The National Transportation Safety Board deter...
# Name: ProbableCause, Length: 545, dtype: object

# %%
# Remove Tags
def remove_tags(text):
  remove = re.compile(r'')
  return re.sub(remove, '', text)

flight_df['ProbableCause'] = flight_df['ProbableCause'].apply(remove_tags)

# %%
# Remove Special Characters
def special_char(text):
  reviews = ''
  for x in text:
    if x.isalnum():
      reviews = reviews + x
    else:
      reviews = reviews + ' '
  return reviews

flight_df['ProbableCause'] = flight_df['ProbableCause'].apply(special_char)

# %%
# Convert to Lower Case
def convert_lower(text):
   return text.lower()

flight_df['ProbableCause'] = flight_df['ProbableCause'].apply(convert_lower)
flight_df['ProbableCause'][1]
# Out:
# 'the pilot s failure attain proper touchdown point runway landing gusting wind conditions  resulted runway overrun  contributing accident pilot s distraction due electrical issue '

# %%
# Remove Stopwords
def remove_stopwords(text):
  stop_words = set(stopwords.words('english'))
  words = word_tokenize(text)
  return [x for x in words if x not in stop_words]

flight_df['ProbableCause'] = flight_df['ProbableCause'].apply(remove_stopwords)
flight_df['ProbableCause'][1]
# Out:
# ['pilot',
#  'failure',
#  'attain',
#  'proper',
#  'touchdown',
#  'point',
#  'runway',
#  'landing',
#  'gusting',
#  'wind',
#  'conditions',
#  'resulted',
#  'runway',
#  'overrun',
#  'contributing',
#  'accident',
#  'pilot',
#  'distraction',
#  'due',
#  'electrical',
#  'issue']

# %%
import nltk

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\humerayasmeen.s\AppData\Roaming\nltk_data...
# True

# %%
# Lemmatizing Words
def lemmatize_word(text):
  wordnet = WordNetLemmatizer()
  return " ".join([wordnet.lemmatize(word) for word in text])

flight_df['ProbableCause'] = flight_df['ProbableCause'].apply(lemmatize_word)
flight_df['ProbableCause'][1]
# Out:
# 'pilot failure attain proper touchdown point runway landing gusting wind condition resulted runway overrun contributing accident pilot distraction due electrical issue'

# %%
# Final Data after cleaning
flight_df.head()
# Out:
#    index                     EventDate          City       State  \
# 0      0 1970-01-01 00:00:00.000044464     Patterson   Louisiana
# 1      1 1970-01-01 00:00:00.000044458  Grass Valley  California
# 2      2 1970-01-01 00:00:00.000044456   Osage Beach    Missouri
# 3      3 1970-01-01 00:00:00.000044455  Battle Creek    Michigan
# 4      4 1970-01-01 00:00:00.000044455     Ypsilanti    Michigan
#
#    HasSafetyRec      Mode HighestInjuryLevel  FatalInjuryCount  \
# 0         False  Aviation               None                 0
# 1         False  Aviation               None                 0
# 2         False  Aviation               None                 0
# 3         False  Aviation               None                 0
# 4         False  Aviation               None                 0
#
#    SeriousInjuryCount  MinorInjuryCount     Category  \
# 0                   0                 0  pilot_issue
# 1                   0                 0  pilot_issue
# 2                   0                 0  pilot_issue
# 3                   0                 0  pilot_issue
# 4                   0                 0  pilot_issue
#
#                                        ProbableCause  \
# 0  pilot failure maintain adequate clearance park...
# 1  pilot failure attain proper touchdown point ru...
# 2  pilot flight instructor failure ensure landing...
# 3  pilot failure maintain directional control tai...
# 4  pilot failure maintain directional control tax...
#
#                                             Findings
# 0  Personnel issues - Psychological - Attention/m...
# 1  Aircraft - Aircraft systems - Communications s...
# 2  Personnel issues - Task performance - Use equi...
# 3  Personnel issues - Task performance - Use equi...
# 4  Personnel issues - Task performance - Use equi...

# %%
flight_df
# Out:
#      index                     EventDate            City       State  \
# 0        0 1970-01-01 00:00:00.000044464       Patterson   Louisiana
# 1        1 1970-01-01 00:00:00.000044458    Grass Valley  California
# 2        2 1970-01-01 00:00:00.000044456     Osage Beach    Missouri
# 3        3 1970-01-01 00:00:00.000044455    Battle Creek    Michigan
# 4        4 1970-01-01 00:00:00.000044455       Ypsilanti    Michigan
# ..     ...                           ...             ...         ...
# 540    540 1970-01-01 00:00:00.000044065             Tok      Alaska
# 541    541 1970-01-01 00:00:00.000044064        Kotzebue      Alaska
# 542    542 1970-01-01 00:00:00.000044064          Athens       Texas
# 543    543 1970-01-01 00:00:00.000044064       Corsicana       Texas
# 544    544 1970-01-01 00:00:00.000044064  Corpus Christi       Texas
#
#      HasSafetyRec      Mode HighestInjuryLevel  FatalInjuryCount  \
# 0           False  Aviation               None                 0
# 1           False  Aviation               None                 0
# 2           False  Aviation               None                 0
# 3           False  Aviation               None                 0
# 4           False  Aviation               None                 0
# ..            ...       ...                ...               ...
# 540         False  Aviation               None                 0
# 541         False  Aviation               None                 0
# 542         False  Aviation               None                 0
# 543         False  Aviation               None                 0
# 544         False    Marine              Fatal                 4
#
#      SeriousInjuryCount  MinorInjuryCount           Category  \
# 0                     0                 0        pilot_issue
# 1                     0                 0        pilot_issue
# 2                     0                 0        pilot_issue
# 3                     0                 0        pilot_issue
# 4                     0                 0        pilot_issue
# ..                  ...               ...                ...
# 540                   0                 0        pilot_issue
# 541                   0                 0        pilot_issue
# 542                   0                 0        pilot_issue
# 543                   0                 0        pilot_issue
# 544                   6                 0  environment_issue
#
#                                          ProbableCause  \
# 0    pilot failure maintain adequate clearance park...
# 1    pilot failure attain proper touchdown point ru...
# 2    pilot flight instructor failure ensure landing...
# 3    pilot failure maintain directional control tai...
# 4    pilot failure maintain directional control tax...
# ..                                                 ...
# 540  student pilot failure maintain directional con...
# 541  pilot failure maintain airspeed conducive flig...
# 542  pilot failure extend landing gear approach lan...
# 543  student pilot maintain control airplane takeof...
# 544  national transportation safety board determine...
#
#                                               Findings
# 0    Personnel issues - Psychological - Attention/m...
# 1    Aircraft - Aircraft systems - Communications s...
# 2    Personnel issues - Task performance - Use equi...
# 3    Personnel issues - Task performance - Use equi...
# 4    Personnel issues - Task performance - Use equi...
# ..                                                 ...
# 540  Aircraft - Aircraft oper/perf/capability - Per...
# 541  Aircraft - Aircraft oper/perf/capability - Per...
# 542  Personnel issues - Task performance - Use equi...
# 543  Aircraft - Aircraft oper/perf/capability - Per...
# 544  Organizational issues - Support/oversight/moni...
#
# [545 rows x 13 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

x = np.array(flight_df.iloc[:,0].values)
y = np.array(flight_df['Category'].values)

cv = CountVectorizer(max_features = 5000)
x = cv.fit_transform(flight_df.ProbableCause).toarray()
print("X.shape = ",x.shape)
print("y.shape = ",y.shape)
# Out:
# X.shape =  (545, 880)
# y.shape =  (545,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42, shuffle = True)

print(len(x_train))
print(len(x_test))
# Out:
# 381
# 164

# %%
#create list of model and accuracy dicts

perform_list = [ ]

def run_model(model_name):
    mdl=''
    if model_name == 'Logistic Regression':
        mdl = LogisticRegression()
    elif model_name == 'Random Forest':
        mdl = RandomForestClassifier(n_estimators=100 ,criterion='entropy' , random_state=0)
    elif model_name == 'Multinomial Naive Bayes':
        mdl = MultinomialNB(alpha=1.0,fit_prior=True)
    elif model_name == 'Support Vector Classifer':
        mdl = SVC()
    elif model_name == 'Decision Tree Classifier':
        mdl = DecisionTreeClassifier()
    elif model_name == 'K Nearest Neighbour':
        mdl = KNeighborsClassifier(n_neighbors=10 , metric= 'minkowski' , p = 4)
    elif model_name == 'Gaussian Naive Bayes':
        mdl = GaussianNB()

    oneVsRest = OneVsRestClassifier(mdl)
    oneVsRest.fit(x_train, y_train)
    y_pred = oneVsRest.predict(x_test)

    # Performance metrics

    accuracy = round(accuracy_score(y_test, y_pred) * 100, 2)
    
    # Get precision, recall, f1 scores
    precision, recall, f1score, support = score(y_test, y_pred, average='micro')
    
    print(f'Test Accuracy Score of Basic {model_name} {accuracy}%')
    print(f'Precision : {precision}')
    print(f'Recall : {recall}')
    print(f'F1-score : {f1score}')

    # Add performance parameters to list

    perform_list.append(dict([('Model', model_name),('Test Accuracy', round(accuracy, 2)),
                              ('Precision', round(precision, 2)),('Recall', round(recall, 2)),
                              ('F1', round(f1score, 2))]))

# %%
run_model('Logistic Regression')
# Out:
# Test Accuracy Score of Basic Logistic Regression 89.02%
# Precision : 0.8902439024390244
# Recall : 0.8902439024390244
# F1-score : 0.8902439024390244

# %%
run_model('Random Forest')
# Out:
# Test Accuracy Score of Basic Random Forest 88.41%
# Precision : 0.8841463414634146
# Recall : 0.8841463414634146
# F1-score : 0.8841463414634146

# %%
run_model('Multinomial Naive Bayes')
# Out:
# Test Accuracy Score of Basic Multinomial Naive Bayes 86.59%
# Precision : 0.8658536585365854
# Recall : 0.8658536585365854
# F1-score : 0.8658536585365854

# %%
run_model('Support Vector Classifer')
# Out:
# Test Accuracy Score of Basic Support Vector Classifer 86.59%
# Precision : 0.8658536585365854
# Recall : 0.8658536585365854
# F1-score : 0.8658536585365854

# %%
run_model('Decision Tree Classifier')
# Out:
# Test Accuracy Score of Basic Decision Tree Classifier 85.98%
# Precision : 0.8597560975609756
# Recall : 0.8597560975609756
# F1-score : 0.8597560975609756

# %%
run_model('K Nearest Neighbour')
# Out:
# Test Accuracy Score of Basic K Nearest Neighbour 85.37%
# Precision : 0.8536585365853658
# Recall : 0.8536585365853658
# F1-score : 0.8536585365853658

# %%
run_model('Gaussian Naive Bayes')
# Out:
# Test Accuracy Score of Basic Gaussian Naive Bayes 81.1%
# Precision : 0.8109756097560976
# Recall : 0.8109756097560976
# F1-score : 0.8109756097560975

# %%
model_performance = pd.DataFrame(data=perform_list)
model_performance
# Out:
#                       Model  Test Accuracy  Precision  Recall    F1
# 0       Logistic Regression          89.02       0.89    0.89  0.89
# 1             Random Forest          88.41       0.88    0.88  0.88
# 2   Multinomial Naive Bayes          86.59       0.87    0.87  0.87
# 3  Support Vector Classifer          86.59       0.87    0.87  0.87
# 4  Decision Tree Classifier          85.98       0.86    0.86  0.86
# 5       K Nearest Neighbour          85.37       0.85    0.85  0.85
# 6      Gaussian Naive Bayes          81.10       0.81    0.81  0.81

# %%
classifier = LogisticRegression().fit(x_train, y_train)

# %%
y_pred1 = cv.transform(['The pilot’s inadequate fuel management, resulted total loss engine power due fuel starvation, pilot’s inadequate preflight inspection preflight fuel planning.'])
y_pred2 = cv.transform(['The airplane’s encounter turbulence descent, resulted serious injury flight attendant.'])

# %%
pred = classifier.predict(y_pred1)

print(pred)
# Out:
# ['pilot_issue']

# %%
pred
# Out:
# array(['pilot_issue'], dtype=object)

# %%
test = pd.read_excel("aircraft_test.xlsx", usecols = ['Category', 'ProbableCause'])

# %%
test
# Out:
#      Category                                      ProbableCause
# 0         NaN  The pilot's failure maintain directional contr...
# 1         NaN      The pilot's loss directional control landing.
# 2         NaN  The National Transportation Safety Board deter...
# 3         NaN  The pilot's failure maintain clearance taxiway...
# 4         NaN  The pilot’s failure maintain altitude short fi...
# ..        ...                                                ...
# 450       NaN  The pilot's poor preflight planning, failed ve...
# 451       NaN  The pilot's failure maintain proper descent ra...
# 452       NaN  The airplane’s encounter turbulence descent, r...
# 453       NaN  The pilot’s inadequate fuel management, result...
# 454       NaN  The National Transportation Safety Board deter...
#
# [455 rows x 2 columns]

# %%
test_input = cv.transform(test.ProbableCause.values)
test_pred = classifier.predict(test_input)
test['Category'] = test_pred
test
# Out:
#               Category                                      ProbableCause
# 0          pilot_issue  The pilot's failure maintain directional contr...
# 1          pilot_issue      The pilot's loss directional control landing.
# 2         flight_issue  The National Transportation Safety Board deter...
# 3          pilot_issue  The pilot's failure maintain clearance taxiway...
# 4          pilot_issue  The pilot’s failure maintain altitude short fi...
# ..                 ...                                                ...
# 450        pilot_issue  The pilot's poor preflight planning, failed ve...
# 451        pilot_issue  The pilot's failure maintain proper descent ra...
# 452  environment_issue  The airplane’s encounter turbulence descent, r...
# 453        pilot_issue  The pilot’s inadequate fuel management, result...
# 454        pilot_issue  The National Transportation Safety Board deter...
#
# [455 rows x 2 columns]

# %%
test.to_csv("Aircraft_final.csv")

# %%
import pickle

# %%
pickle_out=open("flight_risk_flask.pkl","wb")
pickle.dump(classifier,pickle_out)
loaded_model=pickle.load(open("flight_risk_flask.pkl","rb"))
loaded_model.predict('Aircraft - Aircraft oper/perf/capability - Performance/control parameters - Directional control - Not attained/maintained, Personnel issues - Task performance - Use of equip/info - Aircraft control - Pilot')
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-402-4017eeb256ca> in <module>
#       2 pickle.dump(classifier,pickle_out)
#       3 loaded_model=pickle.load(open("flight_risk_flask.pkl","rb"))
# ----> 4 loaded_model.predict('Aircraft - Aircraft oper/perf/capability - Performance/control parameters - Directional control - Not attained/maintained, Personnel issues - Task performance - Use of equip/info - Aircraft control - Pilot')
#       5 result=loaded_model.score(x_test,y_test)
#       6 print(result)
#
# ~\Anaconda\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     423             Predicted class label per sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# ~\Anaconda\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     405         check_is_fitted(self)
#     406
# --> 407         X = self._validate_data(X, accept_sparse="csr", reset=False)
#     408         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     409         return scores.ravel() if scores.shape[1] == 1 else scores
#
# ~\Anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     559             raise ValueError("Validation should be done on X, y or both.")
#     560         elif not no_val_X and no_val_y:
# --> 561             X = check_array(X, **check_params)
#     562             out = X
#     563         elif no_val_X and not no_val_y:
#
# ~\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     751             # If input is scalar raise error
#     752             if array.ndim == 0:
# --> 753                 raise ValueError(
#     754                     "Expected 2D array, got scalar array instead:\narray={}.\n"
#     755                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got scalar array instead:
# array=Aircraft - Aircraft oper/perf/capability - Performance/control parameters - Directional control - Not attained/maintained, Personnel issues - Task performance - Use of equip/info - Aircraft control - Pilot.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
test_input = cv.transform(['Aircraft - Aircraft oper/perf/capability - Performance/control parameters - Directional control - Not attained/maintained, Personnel issues - Task performance - Use of equip/info - Aircraft control - Pilot'])
test_pred = classifier.predict(test_input)

# %%
test_pred

# %%
test_input
# Out:
# <455x880 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5316 stored elements in Compressed Sparse Row format>
